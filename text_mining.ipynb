# %%
import pandas as pd
import numpy as np
import nltk
import os
import nltk.corpus

# %%
data = open('C:/Users/Bronson/Desktop/Data Mining/Rabi/text_mining/docs/ancient_txt.txt', 'r+')
text = ""
text = data.read()
print(text)
# Out:
# The source for this era is the Cheitharol Kumbaba, the royal chronicle of Manipur or Kangleipak.
# Nongda Lairen Pakhangba (33â€“154 AD) was ruler and the creator of Manipur (or Meeteileipak or Kangleipak). He was the first crowned historical ruler whose reign began in 33 according to the Cheitharol Kumbaba. Meitei culture took root during the reign of Pakhangba as did sagol kangjei (polo), with the first match played between the chiefs of different regions. Polo was played in imitation of a game from the traditional Hayachak era. Laisna took a major role in organizing the game.
# Pakhangba was succeeded by his son, Khuiyoi Tompok, in 154 AD. Known as the inventor of the drum (pung), his reign was a peaceful one. Technical innovation in metallurgy was also recorded in the chronicle.
# Naophangba (428â€“518 AD)
# The treatise on the construction of the places of Kangla and Kangla Houba are believed to have been written by Ashangba Laiba.
# Loiyamba Shinyen (1074â€“1122 AD) was known as the "Great law Giver", his reign was an important period in the history of Kangleibak. Along with the military consolidation of the kingdom, Loiyamba introduced administrative reforms, which provided the backbone of the kingdom's administration for the next seven centuries. He systematized the administrative divisions of the country by creating six lups or divisions as well as introducing the Pana System. He left a well-organized society and economy in Meeteileipak.

# %%
# importing word_tokenize from nltk
from nltk.tokenize import word_tokenize
# Passing the string text into word tokenize for breaking the sentences
token = word_tokenize(text)
token
# Out:
# ['The',
#  'source',
#  'for',
#  'this',
#  'era',
#  'is',
#  'the',
#  'Cheitharol',
#  'Kumbaba',
#  ',',
#  'the',
#  'royal',
#  'chronicle',
#  'of',
#  'Manipur',
#  'or',
#  'Kangleipak',
#  '.',
#  'Nongda',
#  'Lairen',
#  'Pakhangba',
#  '(',
#  '33â€',
#  '“',
#  '154',
#  'AD',
#  ')',
#  'was',
#  'ruler',
#  'and',
#  'the',
#  'creator',
#  'of',
#  'Manipur',
#  '(',
#  'or',
#  'Meeteileipak',
#  'or',
#  'Kangleipak',
#  ')',
#  '.',
#  'He',
#  'was',
#  'the',
#  'first',
#  'crowned',
#  'historical',
#  'ruler',
#  'whose',
#  'reign',
#  'began',
#  'in',
#  '33',
#  'according',
#  'to',
#  'the',
#  'Cheitharol',
#  'Kumbaba',
#  '.',
#  'Meitei',
#  'culture',
#  'took',
#  'root',
#  'during',
#  'the',
#  'reign',
#  'of',
#  'Pakhangba',
#  'as',
#  'did',
#  'sagol',
#  'kangjei',
#  '(',
#  'polo',
#  ')',
#  ',',
#  'with',
#  'the',
#  'first',
#  'match',
#  'played',
#  'between',
#  'the',
#  'chiefs',
#  'of',
#  'different',
#  'regions',
#  '.',
#  'Polo',
#  'was',
#  'played',
#  'in',
#  'imitation',
#  'of',
#  'a',
#  'game',
#  'from',
#  'the',
#  'traditional',
#  'Hayachak',
#  'era',
#  '.',
#  'Laisna',
#  'took',
#  'a',
#  'major',
#  'role',
#  'in',
#  'organizing',
#  'the',
#  'game',
#  '.',
#  'Pakhangba',
#  'was',
#  'succeeded',
#  'by',
#  'his',
#  'son',
#  ',',
#  'Khuiyoi',
#  'Tompok',
#  ',',
#  'in',
#  '154',
#  'AD',
#  '.',
#  'Known',
#  'as',
#  'the',
#  'inventor',
#  'of',
#  'the',
#  'drum',
#  '(',
#  'pung',
#  ')',
#  ',',
#  'his',
#  'reign',
#  'was',
#  'a',
#  'peaceful',
#  'one',
#  '.',
#  'Technical',
#  'innovation',
#  'in',
#  'metallurgy',
#  'was',
#  'also',
#  'recorded',
#  'in',
#  'the',
#  'chronicle',
#  '.',
#  'Naophangba',
#  '(',
#  '428â€',
#  '“',
#  '518',
#  'AD',
#  ')',
#  'The',
#  'treatise',
#  'on',
#  'the',
#  'construction',
#  'of',
#  'the',
#  'places',
#  'of',
#  'Kangla',
#  'and',
#  'Kangla',
#  'Houba',
#  'are',
#  'believed',
#  'to',
#  'have',
#  'been',
#  'written',
#  'by',
#  'Ashangba',
#  'Laiba',
#  '.',
#  'Loiyamba',
#  'Shinyen',
#  '(',
#  '1074â€',
#  '“',
#  '1122',
#  'AD',
#  ')',
#  'was',
#  'known',
#  'as',
#  'the',
#  '``',
#  'Great',
#  'law',
#  'Giver',
#  "''",
#  ',',
#  'his',
#  'reign',
#  'was',
#  'an',
#  'important',
#  'period',
#  'in',
#  'the',
#  'history',
#  'of',
#  'Kangleibak',
#  '.',
#  'Along',
#  'with',
#  'the',
#  'military',
#  'consolidation',
#  'of',
#  'the',
#  'kingdom',
#  ',',
#  'Loiyamba',
#  'introduced',
#  'administrative',
#  'reforms',
#  ',',
#  'which',
#  'provided',
#  'the',
#  'backbone',
#  'of',
#  'the',
#  'kingdom',
#  "'s",
#  'administration',
#  'for',
#  'the',
#  'next',
#  'seven',
#  'centuries',
#  '.',
#  'He',
#  'systematized',
#  'the',
#  'administrative',
#  'divisions',
#  'of',
#  'the',
#  'country',
#  'by',
#  'creating',
#  'six',
#  'lups',
#  'or',
#  'divisions',
#  'as',
#  'well',
#  'as',
#  'introducing',
#  'the',
#  'Pana',
#  'System',
#  '.',
#  'He',
#  'left',
#  'a',
#  'well-organized',
#  'society',
#  'and',
#  'economy',
#  'in',
#  'Meeteileipak',
#  '.']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(token)
fdist
# Out:
# FreqDist({'the': 25, '.': 14, 'of': 12, ',': 8, 'was': 8, 'in': 8, '(': 6, ')': 6, 'as': 5, 'or': 4, ...})

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bronson\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
a = set(stopwords.words('english'))
stopwords = [x for x in token if x not in a]
print(stopwords)
# Out:
# ['The', 'source', 'era', 'Cheitharol', 'Kumbaba', ',', 'royal', 'chronicle', 'Manipur', 'Kangleipak', '.', 'Nongda', 'Lairen', 'Pakhangba', '(', '33â€', '“', '154', 'AD', ')', 'ruler', 'creator', 'Manipur', '(', 'Meeteileipak', 'Kangleipak', ')', '.', 'He', 'first', 'crowned', 'historical', 'ruler', 'whose', 'reign', 'began', '33', 'according', 'Cheitharol', 'Kumbaba', '.', 'Meitei', 'culture', 'took', 'root', 'reign', 'Pakhangba', 'sagol', 'kangjei', '(', 'polo', ')', ',', 'first', 'match', 'played', 'chiefs', 'different', 'regions', '.', 'Polo', 'played', 'imitation', 'game', 'traditional', 'Hayachak', 'era', '.', 'Laisna', 'took', 'major', 'role', 'organizing', 'game', '.', 'Pakhangba', 'succeeded', 'son', ',', 'Khuiyoi', 'Tompok', ',', '154', 'AD', '.', 'Known', 'inventor', 'drum', '(', 'pung', ')', ',', 'reign', 'peaceful', 'one', '.', 'Technical', 'innovation', 'metallurgy', 'also', 'recorded', 'chronicle', '.', 'Naophangba', '(', '428â€', '“', '518', 'AD', ')', 'The', 'treatise', 'construction', 'places', 'Kangla', 'Kangla', 'Houba', 'believed', 'written', 'Ashangba', 'Laiba', '.', 'Loiyamba', 'Shinyen', '(', '1074â€', '“', '1122', 'AD', ')', 'known', '``', 'Great', 'law', 'Giver', "''", ',', 'reign', 'important', 'period', 'history', 'Kangleibak', '.', 'Along', 'military', 'consolidation', 'kingdom', ',', 'Loiyamba', 'introduced', 'administrative', 'reforms', ',', 'provided', 'backbone', 'kingdom', "'s", 'administration', 'next', 'seven', 'centuries', '.', 'He', 'systematized', 'administrative', 'divisions', 'country', 'creating', 'six', 'lups', 'divisions', 'well', 'introducing', 'Pana', 'System', '.', 'He', 'left', 'well-organized', 'society', 'economy', 'Meeteileipak', '.']
